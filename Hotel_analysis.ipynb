# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Hotel book.csv")
data.head(10)
# Out:
#          Date  Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# 0  01/01/2024      1        1  Winter        1            50000    80000
# 1  02/01/2024      1        2  Winter        0            60000    85000
# 2  03/01/2024      1        3  Winter        0            70000    90000
# 3  04/01/2024      1        4  Winter        1            50000    80000
# 4  05/01/2024      1        5  Winter        0            60000    85000
# 5  06/01/2024      1        6  Winter        0            70000    90000
# 6  07/01/2024      1        7  Winter        0            50000    80000
# 7  08/01/2024      1        1  Winter        0            60000    85000
# 8  09/01/2024      1        2  Winter        0            70000    90000
# 9  10/01/2024      1        3  Winter        0            50000    80000
#
#    Room_Revenue  Occupancy_Rate  ADR  ...  Occupancy_Managed_Guests  \
# 0         45000            0.75  120  ...                        75
# ...

# %%
data.shape
# Out:
# (109, 38)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      109 non-null    object
#  1   Month                     109 non-null    int64
#  2   Weekday                   109 non-null    int64
#  3   Season                    109 non-null    object
#  4   Holiday                   109 non-null    int64
#  5   Marketing_Spend           109 non-null    int64
#  6   Revenue                   109 non-null    int64
#  7   Room_Revenue              109 non-null    int64
#  8   Occupancy_Rate            109 non-null    float64
#  9   ADR                       109 non-null    int64
#  10  RevPAR                    109 non-null    float64
#  11  Available_Rooms           109 non-null    int64
#  12  Reserved_Rooms            109 non-null    int64
#  13  Booking_Channel           109 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# Date                          0
# Month                         0
# Weekday                       0
# Season                        0
# Holiday                       0
# Marketing_Spend               0
# Revenue                       0
# Room_Revenue                  0
# Occupancy_Rate                0
# ADR                           0
# RevPAR                        0
# Available_Rooms               0
# Reserved_Rooms                0
# Booking_Channel               0
# Guest_Type                    0
# Market_Segment                0
# Guest_Country                 0
# Complaints                    0
# Compliment                    0
# Bookings                      0
# No_Shows                      0
# Cancellations                 0
# Checkouts                     0
# New_Bookings                  0
# Checkins                      0
# Average_Review_Score          0
# Revenue_Managed_Guests        0
# RevPAR_Managed_Guests         0
# Occupancy_Managed_Guests      0
# ...

# %%
data.describe()
# Out:
#             Month     Weekday     Holiday  Marketing_Spend       Revenue  \
# count  109.000000  109.000000  109.000000       109.000000    109.000000
# mean     3.266055    3.908257    0.119266     59954.128440  84917.431193
# std      2.406173    2.030058    0.325598      8093.647853   4501.292901
# min      1.000000    1.000000    0.000000     50000.000000  78000.000000
# 25%      1.000000    2.000000    0.000000     50000.000000  80000.000000
# 50%      2.000000    4.000000    0.000000     60000.000000  85000.000000
# 75%      7.000000    6.000000    0.000000     70000.000000  90000.000000
# max      7.000000    7.000000    1.000000     70000.000000  93000.000000
#
#        Room_Revenue  Occupancy_Rate         ADR      RevPAR  Available_Rooms  \
# count    109.000000      109.000000  109.000000  109.000000       109.000000
# mean   47009.174312        0.774862  124.743119   95.289083        31.376147
# std     2057.035861        0.023516    5.191524    7.906691         1.451621
# ...

# %% [markdown]
# # Descriptive Stat

# %%
descriptive_stat = data.describe(include='all')
print(descriptive_stat)
# Out:
#               Date       Month     Weekday  Season     Holiday  \
# count          109  109.000000  109.000000     109  109.000000
# unique         109         NaN         NaN       3         NaN
# top     01/01/2024         NaN         NaN  Winter         NaN
# freq             1         NaN         NaN      60         NaN
# mean           NaN    3.266055    3.908257     NaN    0.119266
# std            NaN    2.406173    2.030058     NaN    0.325598
# min            NaN    1.000000    1.000000     NaN    0.000000
# 25%            NaN    1.000000    2.000000     NaN    0.000000
# 50%            NaN    2.000000    4.000000     NaN    0.000000
# 75%            NaN    7.000000    6.000000     NaN    0.000000
# max            NaN    7.000000    7.000000     NaN    1.000000
#
#         Marketing_Spend       Revenue  Room_Revenue  Occupancy_Rate  \
# count        109.000000    109.000000    109.000000      109.000000
# unique              NaN           NaN           NaN             NaN
# ...

# %% [markdown]
# # The descriptive statistics provide an overview of the dataset:
#
# Date: Unique dates range from January 1st, 2024, to April 18th, 2024.
#
# Month: Data spans from January (1) to July (7).
#
# Weekday: Covers all days of the week.
#
# Season: Only three unique seasons are listed.
#
# Holiday: Most days are non-holidays.
#
#
# Marketing_Spend: Ranges from 50,000 to 70,000.
#
# Revenue: Ranges from 78,000 to 93,000.
#
# Room_Revenue: Ranges from 43,000 to 50,000.
#
# Occupancy_Rate: Average is 0.77, ranging from 0.73 to 0.81.
#
# ADR: Ranges from 115 to 135.
#
# Operating_Expenses: Ranges from 10,000 to 12,000.
#
# Fixed_Costs: Ranges from 4,000 to 7,000.
#
# Variable_Costs: Ranges from 58,000 to 76,000.
#
# Total_Costs: Ranges from 12,000 to 21,500.
#
# Profit: Missing for all records.

# %% [markdown]
# # Time series analysis

# %%
# Convert 'Date' column to datetime format
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')

# Set 'Date' as the index
data.set_index('Date', inplace=True)

# Select only numeric columns for the time series analysis
numeric_columns = ['Marketing_Spend', 'Revenue', 'Room_Revenue', 'Occupancy_Rate', 'ADR', 
                   'Occupancy_Managed_Guests', 'RevPAR_All', 'Occupancy_All', 
                   'Room_Revenue_All', 'Total_Revenue', 'Operating_Expenses', 
                   'Fixed_Costs', 'Variable_Costs', 'Total_Costs', 'Profit']

# Resample data to monthly frequency and calculate the mean for numeric columns
monthly_data = data[numeric_columns].resample('M').mean()

# Plotting monthly Revenue and Occupancy Rate
fig, ax1 = plt.subplots(figsize=(14, 7))

ax1.set_title('Monthly Revenue and Occupancy Rate')
ax1.set_xlabel('Date')

ax1.plot(monthly_data.index, monthly_data['Revenue'], color='tab:blue', label='Revenue')
ax1.set_ylabel('Revenue', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(monthly_data.index, monthly_data['Occupancy_Rate'], color='tab:orange', label='Occupancy Rate')
ax2.set_ylabel('Occupancy Rate', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

fig.tight_layout()
plt.legend(loc='upper left')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7808\2042791511.py:14: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_data = data[numeric_columns].resample('M').mean()

# %%
# Plotting multiple time series

# Plotting Marketing Spend and Revenue
fig, ax1 = plt.subplots(figsize=(14, 7))

ax1.set_title('Monthly Marketing Spend and Revenue')
ax1.set_xlabel('Date')

ax1.plot(monthly_data.index, monthly_data['Marketing_Spend'], color='tab:blue', label='Marketing Spend')
ax1.set_ylabel('Marketing Spend', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(monthly_data.index, monthly_data['Revenue'], color='tab:orange', label='Revenue')
ax2.set_ylabel('Revenue', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

fig.tight_layout()
plt.legend(loc='upper left')
plt.show()

# Plotting Room Revenue and ADR
fig, ax1 = plt.subplots(figsize=(14, 7))

ax1.set_title('Monthly Room Revenue and ADR')
ax1.set_xlabel('Date')

ax1.plot(monthly_data.index, monthly_data['Room_Revenue'], color='tab:blue', label='Room Revenue')
ax1.set_ylabel('Room Revenue', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(monthly_data.index, monthly_data['ADR'], color='tab:orange', label='ADR')
ax2.set_ylabel('ADR', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

fig.tight_layout()
plt.legend(loc='upper left')
plt.show()

# Plotting Total Revenue and Occupancy Rate
fig, ax1 = plt.subplots(figsize=(14, 7))

ax1.set_title('Monthly Total Revenue and Occupancy Rate')
ax1.set_xlabel('Date')

ax1.plot(monthly_data.index, monthly_data['Total_Revenue'], color='tab:blue', label='Total Revenue')
ax1.set_ylabel('Total Revenue', color='tab:blue')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.plot(monthly_data.index, monthly_data['Occupancy_Rate'], color='tab:orange', label='Occupancy Rate')
ax2.set_ylabel('Occupancy Rate', color='tab:orange')
ax2.tick_params(axis='y', labelcolor='tab:orange')

fig.tight_layout()
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# # Correlation :

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])

correlations = numeric_data.corr()
correlations
# Out:
#                              Month   Weekday   Holiday  Marketing_Spend  \
# Month                     1.000000 -0.010121 -0.159064         0.012519
# Weekday                  -0.010121  1.000000  0.058732         0.022283
# Holiday                  -0.159064  0.058732  1.000000        -0.033041
# Marketing_Spend           0.012519  0.022283 -0.033041         1.000000
# Revenue                  -0.040698  0.033615 -0.012172         0.987278
# Room_Revenue             -0.346580  0.002421  0.053650         0.873177
# Occupancy_Rate           -0.186715  0.019129  0.020303         0.957134
# ADR                      -0.174598  0.043428  0.034726         0.935154
# RevPAR                   -0.449316  0.010915  0.094887         0.821076
# Available_Rooms          -0.230387  0.036955  0.021747         0.915673
# Reserved_Rooms            0.215157 -0.008412 -0.001113        -0.809496
# Market_Segment            0.136287 -0.018404 -0.008666        -0.773399
# ...

# %%
numeric_data = data.select_dtypes(include=['float64', 'int64'])

# Calculate the correlation matrix
correlations = numeric_data.corr()

# Create the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlations, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # Profit Calculation

# %%
data['Profit'] = data['Total_Revenue'] - data['Total_Costs']

# %%
data.head(10)
# Out:
#             Month  Weekday  Season  Holiday  Marketing_Spend  Revenue  \
# Date
# 2024-01-01      1        1  Winter        1            50000    80000
# 2024-01-02      1        2  Winter        0            60000    85000
# 2024-01-03      1        3  Winter        0            70000    90000
# 2024-01-04      1        4  Winter        1            50000    80000
# 2024-01-05      1        5  Winter        0            60000    85000
# 2024-01-06      1        6  Winter        0            70000    90000
# 2024-01-07      1        7  Winter        0            50000    80000
# 2024-01-08      1        1  Winter        0            60000    85000
# 2024-01-09      1        2  Winter        0            70000    90000
# 2024-01-10      1        3  Winter        0            50000    80000
#
#             Room_Revenue  Occupancy_Rate  ADR  RevPAR  ...  \
# Date                                                   ...
# 2024-01-01         45000            0.75  120    90.0  ...
# ...

# %%
total_profit = data['Profit'].sum()
print(total_profit)
# Out:
# 4141500

# %% [markdown]
# # Seasonal Impact Calculation

# %%
seasonal_impact = data.groupby(['Season', 'Holiday'])['Revenue'].mean()
print(seasonal_impact)
# Out:
# Season  Holiday
# Spring  0          84687.500000
#         1          88666.666667
# Summer  0          84689.655172
#         1          80000.000000
# Winter  0          85156.862745
#         1          84000.000000
# Name: Revenue, dtype: float64

# %%
seasonal_impact_df = seasonal_impact.reset_index()
seasonal_impact_df.columns = ['Season', 'Holiday', 'Average_Revenue']

# Pivot the DataFrame for the heatmap
heatmap_data = seasonal_impact_df.pivot(index='Season', columns='Holiday', values='Average_Revenue')

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".1f", cmap='YlGnBu', cbar_kws={'label': 'Average Revenue'})
plt.title('Heatmap of Average Revenue by Season and Holiday')
plt.show()
